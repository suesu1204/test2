# %% [markdown]
# <a href="https://colab.research.google.com/github/ililillilili1/test2/blob/DA/page5_ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #연습1

# %%
import pandas as pd
df=pd.read_csv('/content/ta_20240519171208.csv', encoding = 'cp949')
df
# Out:
#         년월   지점  평균기온(℃)  평균최저기온(℃)  평균최고기온(℃)
# 0   Jan-03  119     -4.0       -8.2        0.5
# 1   Feb-03  119      0.7       -3.8        5.3
# 2   Mar-03  119      5.3        0.6       10.1
# 3   Apr-03  119     12.4        7.6       17.9
# 4   May-03  119     18.8       13.2       24.6
# 5   Jun-03  119     21.3       17.5       25.8
# 6   Jul-03  119     23.8       20.5       27.7
# 7   Aug-03  119     24.2       21.3       27.9
# 8   Sep-03  119     21.0       17.2       25.4
# 9   Oct-03  119     13.6        8.4       19.4
# 10  Nov-03  119      9.3        4.8       14.0
# 11  Dec-03  119      0.6       -3.8        5.1

# %%
df.index = df['년월']
df.loc['Dec-03', ['평균최저기온(℃)','평균최고기온(℃)']]
# Out:
# 평균최저기온(℃)   -3.8
# 평균최고기온(℃)    5.1
# Name: Dec-03, dtype: object

# %%
w = df['평균기온(℃)'] >= 20
df[w]
# Out:
#             년월   지점  평균기온(℃)  평균최저기온(℃)  평균최고기온(℃)
# 년월
# Jun-03  Jun-03  119     21.3       17.5       25.8
# Jul-03  Jul-03  119     23.8       20.5       27.7
# Aug-03  Aug-03  119     24.2       21.3       27.9
# Sep-03  Sep-03  119     21.0       17.2       25.4

# %%
w = df['평균기온(℃)'] == df['평균기온(℃)'].max()
df[w]

#?
# Out:
#             년월   지점  평균기온(℃)  평균최저기온(℃)  평균최고기온(℃)
# 년월
# Aug-03  Aug-03  119     24.2       21.3       27.9

# %% [markdown]
# #연습02

# %%
import pandas as pd
df = pd.read_csv('/content/covid.csv',encoding = 'cp949')
df
# Out:
#        항목  사례수    증가    감소  변화없음
# 0    스마트폰  999  78.9   1.7  19.4
# 1    텔레비전  965  68.5   3.9  27.6
# 2  개인용 PC  973  65.7   3.7  30.6
# 3  태블릿 PC  662  46.8   4.2  49.0
# 4     라디오  687  35.5  12.5  52.0
# 5    잡지·책  776  31.3  17.8  50.9
# 6    종이신문  552  17.6  23.2  59.2

# %%
w = df['사례수'] == df['사례수'].max()
df[w]
# Out:
#      항목  사례수    증가   감소  변화없음
# 0  스마트폰  999  78.9  1.7  19.4

# %%
df.sort_values(by='증가')
df.head(3)
# Out:
#        항목  사례수    증가   감소  변화없음
# 0    스마트폰  999  78.9  1.7  19.4
# 1    텔레비전  965  68.5  3.9  27.6
# 2  개인용 PC  973  65.7  3.7  30.6

# %% [markdown]
# #연습3

# %%
import pandas as pd
df = pd.read_csv('/content/vaccine.csv',encoding = 'cp949')
df
# Out:
#            date  subject  day1num  day1sum  day1rate  day2num  day2sum  \
# 0    2021.10.16  9505868    10673  7562283      79.6    66910  6191341
# 1    2021.10.15  9505868    14556  7551829      79.4   133580  6124432
# 2    2021.10.14  9505868     9609  7536654      79.3    94569  5989111
# 3    2021.10.13  9505868     9804  7526430      79.2    77503  5893191
# 4    2021.10.12  9505868    17274  7516070      79.1   110204  5814018
# ..          ...      ...      ...      ...       ...      ...      ...
# 174  2021.04.25  1023346    23323   350631      34.2     3411    18513
# 175  2021.04.24  1023346      200   350427      34.2        0    18513
# 176  2021.04.23  1027740    10195   345764      33.6      119    18376
# 177  2021.04.22  1023538    27074   317386      31.0     2479    15901
# 178  2021.04.21  1019322    22501   291857      28.6     2358    13543
#
#      day2rate
# 0        65.1
# 1        64.4
# 2        63.0
# 3        62.0
# 4        61.2
# ..        ...
# ...

# %%
df.tail()
# Out:
#            date  subject  day1num  day1sum  day1rate  day2num  day2sum  \
# 174  2021.04.25  1023346    23323   350631      34.2     3411    18513
# 175  2021.04.24  1023346      200   350427      34.2        0    18513
# 176  2021.04.23  1027740    10195   345764      33.6      119    18376
# 177  2021.04.22  1023538    27074   317386      31.0     2479    15901
# 178  2021.04.21  1019322    22501   291857      28.6     2358    13543
#
#      day2rate
# 174       1.8
# 175       1.8
# 176       1.8
# 177       1.6
# 178       1.3

# %%
df = df.drop(['date', 'day1sum', 'day1rate', 'day2sum', 'day2rate'], axis=1)
df.head()
# Out:
#    subject  day1num  day2num
# 0  9505868    10673    66910
# 1  9505868    14556   133580
# 2  9505868     9609    94569
# 3  9505868     9804    77503
# 4  9505868    17274   110204

# %%
count = df.count()
mean = df.mean()
std = df.std()
min = df.min()
max = df.max()
df_25 = df/4

summary_df = pd.DataFrame({
    'count': count,
    'mean': mean,
    'std': std,
    'min': min,
    #'25%': df_25,
    'max': max
})

summary_df = summary_df.T

print(summary_df)
# Out:
#             subject        day1num        day2num
# count  1.790000e+02     179.000000     179.000000
# mean   5.086644e+06   40078.150838   34096.636872
# std    3.324235e+06   44231.469656   40745.688278
# min    1.019322e+06       0.000000       0.000000
# max    9.795426e+06  169036.000000  200186.000000

# %%
summary = df.describe()
summary = summary.T
print(summary_df)
# Out:
#             subject       day1num       day2num
# count  1.790000e+02    179.000000    179.000000
# mean   5.086644e+06  40078.150838  34096.636872
# std    3.324235e+06  44231.469656  40745.688278

# %%
dust = pd.read_csv('/content/vaccine.csv',encoding = 'cp949')

# %%
dust['date']=pd.to_datetime(dust['date'])
dust['month']=dust['date'].dt.month
dust = dust.drop(['date'], axis=1)
print(dust)
# Out:
#      subject  day1num  day1sum  day1rate  day2num  day2sum  day2rate  month
# 0    9505868    10673  7562283      79.6    66910  6191341      65.1     10
# 1    9505868    14556  7551829      79.4   133580  6124432      64.4     10
# 2    9505868     9609  7536654      79.3    94569  5989111      63.0     10
# 3    9505868     9804  7526430      79.2    77503  5893191      62.0     10
# 4    9505868    17274  7516070      79.1   110204  5814018      61.2     10
# ..       ...      ...      ...       ...      ...      ...       ...    ...
# 174  1023346    23323   350631      34.2     3411    18513       1.8      4
# 175  1023346      200   350427      34.2        0    18513       1.8      4
# 176  1027740    10195   345764      33.6      119    18376       1.8      4
# 177  1023538    27074   317386      31.0     2479    15901       1.6      4
# 178  1019322    22501   291857      28.6     2358    13543       1.3      4
#
# [179 rows x 8 columns]

# %%
monthly_mean = dust.groupby('month').mean()
print(monthly_mean)
# Out:
#             subject       day1num       day1sum   day1rate       day2num  \
# month
# 4      1.054686e+06  22060.100000  3.860085e+05  36.440000   2304.600000
# 5      1.289918e+06  18225.548387  6.451063e+05  51.435484   9734.000000
# 6      3.167106e+06  55957.200000  2.234760e+06  69.240000  20147.300000
# 7      3.819340e+06  25807.870968  3.064527e+06  80.232258   9934.903226
# 8      6.702049e+06  57667.258065  4.430462e+06  72.509677  55575.000000
# 9      9.556825e+06  65715.000000  6.466827e+06  67.620000  62162.000000
# 10     9.505868e+06   9406.312500  7.486763e+06  78.762500  79900.750000
#
#             day2sum   day2rate
# month
# 4      2.276060e+04   2.140000
# 5      1.661513e+05  12.529032
# 6      6.229332e+05  19.276667
# 7      1.167138e+06  30.467742
# 8      1.984530e+06  31.080645
# 9      3.887544e+06  40.663333
# 10     5.541498e+06  58.343750

# %% [markdown]
# #연습4

# %%
import pandas as pd

signup = pd.read_csv('/content/signup.csv',encoding = 'cp949')
prof = pd.read_csv('/content/professor.csv',encoding = 'cp949')

print(signup)
print(prof)
# Out:
#    수강코드    과목명 담당교수
# 0   111    파이썬  양숙희
# 1   222  데이터분석  오경선
# 2   333   인공지능  장은실
# 3   444   선형대수  황복동
# 4   555   이산수학  정명식
# 5   666  컴퓨터개론  최봉수
# 6   777   자료구조  김진영
# 7   888   정보통신  김진호
#   담당교수     학과
# 0  양숙희  컴퓨터공학
# 1  장은실   정보통신
# 2  오경선   인공지능
# 3  황복동  컴퓨터공학
# 4  정명식   인공지능

# %%
s1 = pd.merge(signup, prof)
s1
# Out:
#    수강코드    과목명 담당교수     학과
# 0   111    파이썬  양숙희  컴퓨터공학
# 1   222  데이터분석  오경선   인공지능
# 2   333   인공지능  장은실   정보통신
# 3   444   선형대수  황복동  컴퓨터공학
# 4   555   이산수학  정명식   인공지능

# %%
s1.grouped = s1.groupby('학과')
prof_count = s1.grouped['담당교수'].nunique()
s2 = prof_count.reset_index()
s2.columns = ['학과', '담당교수']
print(s2)
# Out:
#       학과  담당교수
# 0   인공지능     2
# 1   정보통신     1
# 2  컴퓨터공학     2
